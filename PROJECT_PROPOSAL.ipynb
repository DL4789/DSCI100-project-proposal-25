# %%
This cell will be used as the project proposal.
Summary (description) of datasets:
The dataset players_data has 196 rows and 7 columns of observation, and has variables including (with statistics for applicable columns):
- age, the mean age is 21.14, the min age is 9.00 and the max age is 58.00
- subscribe (whether the player has subscribed to the game)
- name, the name of the surveyed player
- gender, the statistics for gender are: 1.02% agender, 18.88% female, 63.26% male, 7.65% non-binary, 0.51% other, 5.61% prefer not to say, and 3.06% two-spirited
- experience, the statistics are: beginner, amateur, regular, pro, and veteran in ascending order) 
- played_hours, mean is 5.84 hours, min is 0.00 hours, and max is 223.10 hours                                                                                           
Some issues can arise from the data, including:
- Some data from the gender column is "prefer not to say" which may pose problems when finding statistics of 
the player base as this takes up around 5.61 percent of the database
- Some data can be entered incorrectly, people may claim to be the level that they are not
- Measurement error in time played due to lag/error in the data collection regiment
The dataset sessions_data has 1535 rows and 5 columns, with variables including: 
- start_time, the time at which the session started
- end_time, the time at which the session ended
- original_start_time, the miniscule time (very accurate) at which the session started
- original_end_time, the miniscule time (very accurate) at which the session ended
This data has only numerical variables, therefore errors with technology (capturing minuscule times) and other network errors are 
only possible entry errors. I can also see that the original start and end time yield the same values, which may pose a problem
when modeling the data and could be explored deeper into wrangling it into a better form. 

I will address the broad question: We would like to know which "kinds" of players are most likely to contribute a large amount of data
so that we can target those players in our recruiting efforts.
I will then address a more specific question: Can the age and gender of the player predict the output played hours in the dataset players_data?
To find answers to this question, I can use visuals and predictor engines to find patterns and accurate predictions. To wrangle the data, I can isolate the player profile columns
(age and gender) and the played_hours column using select(), then I can remove any unknown entries such as "prefer not to say" in the gender column using filter(), 
as this data isnt contributing to our findings and only takes up around 5.61% of the data. We can also remove rows with NA for the age variable for the same reason. This specific
question will help determine which group of people to target in recruitment, which will make it easier to reach out to the most important crowd of people to maximize effiency in the 
recruitment process. We can use KNN regression to predict this variable, however the gender column must be turned into a numeric variable that corresponds to the gender of the predicted
player.

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
players_data <- read_csv("DATA/players.csv") |>
select(-hashedEmail)
sessions_data <- read_csv("DATA/sessions.csv") |>
select(-hashedEmail)
players_data
sessions_data
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe played_hours name      gender            Age
# 1   Pro         TRUE     30.3         Morgan    Male               9
# 2   Veteran     TRUE      3.8         Christian Male              17
# ...

# %%
mean_age <- players_data |>
summarize(mean_age = mean(Age, na.rm = TRUE))
min_age <- players_data |>
summarize(min_age = min(Age, na.rm  = TRUE))
max_age <- players_data |>
summarize(max_age = max(Age, na.rm = TRUE))
mean_age
min_age
max_age
# Out:
#   mean_age
# 1 21.13918
#   min_age
# 1 9
#   max_age
# 1 58

# %%
prop_gender <- players_data |>
count(gender) |>
mutate(prop = n / sum(n) * 100)
prop_gender
# Out:
#   gender            n   prop
# 1 Agender             2  1.0204082
# 2 Female             37 18.8775510
# 3 Male              124 63.2653061
# 4 Non-binary         15  7.6530612
# 5 Other               1  0.5102041
# 6 Prefer not to say  11  5.6122449
# 7 Two-Spirited        6  3.0612245

# %%
mean_hours <- players_data |>
summarize(mean_hours = mean(played_hours, na.rm = TRUE))
min_hours <- players_data |>
summarize(min_hours = min(played_hours, na.rm  = TRUE))
max_hours <- players_data |>
summarize(max_hours = max(played_hours, na.rm = TRUE))
mean_hours
min_hours
max_hours
# Out:
#   mean_hours
# 1 5.845918
#   min_hours
# 1 0
#   max_hours
# 1 223.1
