# %%
### Project proposal

Summary of datasets:

Players_data:
196 rows and 7 columns:
- age, mean = 21.14, min = 9.00, max = 58.00
- subscribe (to newsletter)
- name
- gender, 1.02% agender, 18.88% female, 63.26% male, 7.65% non-binary, 0.51% other, 5.61% prefer not to say, 3.06% two-spirited
- experience, 17.85% beginner, 32.14% amateur, 18.37% regular, 7.14% pro, 24.49% veteran  
- played_hours, mean = 5.84 hours, min = 0.00 hours, max = 223.10 hours                                                                                           
Issues:
- Data from gender: "prefer not to say" can pose problems when finding statistics of 
the players as this is 5.61% of the database. Same with some Age data "NA", which causes issues in predictions.
- Some data can be entered incorrectly, people may claim to be the level that they are not (dishonesty)
- Measurement error in time played, to error in data collection


Sessions_data: 
1535 rows, 5 columns: 
- start_time, the time session started
- end_time, the time session ended
- original_start_time, the miniscule time session started
- original_end_time, the miniscule time session ended
Issues:
This data has numerical variables, errors with technology (capturing times) and network errors are 
possible entry errors. I observe that the original start and end time yield the same values, which may pose a problem
when modeling the data and should be wrangled into a better form. 

Broad question: We want to know which "kinds" of players are likely to contribute a large amount of data
so we can target players in recruitment.
Specific question: Can age and gender predict output played hours in players_data?
Finding answers to this question, Ill use visuals and predictor engines like KNN regression. To wrangle the data, I can isolate the player profile columns
(age, gender) and the played_hours column using select(), and remove unknown entries "prefer not to say" or "NA" in these columns using filter(),
this data is unimportant to this prediction (see players_tidy). This question will determine which demographic to target in recruitment, 
and will make it easier to reach the important demographic to maximize effiency. 

###Data exploration

The scatter plot (hours_plot) shows much of the data being from younger players (10-30 years), but lacks a pattern for gender. The histogram (hours_histo) shows a clearer 
pattern for age, and shows proportions for each gender category. The data shows a pattern for each age group and gender, with much of the data being in the younger ages and as 
the gender male. 

###Methods and plan 


I propose to use KNN regression to predict hours_played from age and gender. This is appropriate as KNN can is flexible and can follow non-linear relationships like that
of the dataset applied (visit hours_plot). We assume that the data has a pattern of hours played for each predictor (see hours_histo) and the data is scaled with minimal distribution preferance.
Limitations can depend on the K value and sensitivity of scaling the outliers in each class, which may be solved through testing the model. We can tune the KNN model to find the right
K for prediction using vfold on the training data, evaluating RMSE to find the best fitting K. I will turn gender into a numeric value, scale the data, and remove NA values. 
I will split the data: 70% training, 30% testing before fitting the model to the data. 


Below are analyses from players_data:

# %%
library(tidyverse) #needed for this exploration
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
#proportion of each gender as percentages

prop_gender <- players_data |>
count(gender) |>
mutate(proportion = n / sum(n) * 100)
prop_gender
# Out:
#   gender            n   proportion
# 1 Agender             2  1.0204082
# 2 Female             37 18.8775510
# 3 Male              124 63.2653061
# 4 Non-binary         15  7.6530612
# 5 Other               1  0.5102041
# 6 Prefer not to say  11  5.6122449
# 7 Two-Spirited        6  3.0612245

# %%
#mean, max, and min of age

age_table <- tibble(
    statistic = c("Mean_age", "Minimum_age", "Maximum_age"), value = c(mean_age, min_age, max_age))
age_table
# Out:
#   statistic   value
# 1 Mean_age    21.13918
# 2 Minimum_age  9.00000
# 3 Maximum_age 58.00000

# %%
#mean, max, and min of played_hours
age_table <- tibble(
    statistic = c("Mean_hours", "Minimum_hours", "Maximum_hours"), value = c(mean_hours, min_hours, max_hours))
age_table
# Out:
#   statistic     value
# 1 Mean_hours      5.845918
# 2 Minimum_hours   0.000000
# 3 Maximum_hours 223.100000

# %%
#below I will wrangle the players_data dataset

# %%
players_tidy <- players_data |>
select(Age, gender, played_hours) |>
filter(Age != "NA", gender != "Prefer not to say")
players_tidy
# Out:
#     Age gender       played_hours
# 1    9  Male         30.3
# 2   17  Male          3.8
# 3   17  Male          0.0
# 4   21  Female        0.7
# 5   21  Male          0.1
# 6   17  Female        0.0
# 7   19  Female        0.0
# 8   21  Male          0.0
# 9   47  Male          0.1
# 10  22  Female        0.0
# 11  23  Female        1.6
# 12  17  Male          0.0
# 13  25  Female        1.5
# 14  22  Male          0.2
# 15  17  Non-binary    0.0
# 16  22  Male          0.0
# 17  17  Female        0.0
# 18  17  Female       48.4
# 19  17  Male          0.5
# 20  19  Male          0.6
# 21  58  Male          0.3
# 22  17  Female        0.1
# 23  17  Male          1.0
# 24  17  Male          0.0
# 25  21  Female        0.7
# 26  28  Female        0.6
# 27  17  Male          0.0
# 28  23  Male          0.0
# 29  23  Male          1.8
# 30  18  Male          0.1
# ⋮   ⋮   ⋮            ⋮
# 154 22  Male          0.0
# 155 21  Male          0.1
# 156 26  Male          1.0
# ...

# %%
# I can do some visual analysis to help see patterns in the data, here is a scatter plot

options(repr.plot.width = 12, repr.plot.height = 15)
hours_plot <- players_tidy |>
ggplot(aes(x = Age, y = played_hours, color = gender)) +
geom_point(size = 2, alpha = 0.6) +
labs(x = "Age of player(years)", y = "Hours played", color = "Gender of player", title = "Age and gender vs played hours")

hours_plot
# Out:
# plot without title

# %%
#We can try a histogram plot

options(repr.plot.width = 17, repr.plot.height = 10)
hours_histo <- players_tidy |>
ggplot(aes(x = Age, fill = gender)) +
geom_histogram() +
facet_grid(.~gender) +
labs(x = "Age of player(years)", y = "Hours played", title = "age vs played hours for each gender")

hours_histo
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
#these datasets can be successfully loaded into the notebook
players_data <- read_csv("DATA/players.csv") 
sessions_data <- read_csv("DATA/sessions.csv")
players_data
sessions_data
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# ...

# %%
#all work below is rough work used to make values for summary stats

# %%
mean_age <- players_data |>
summarize(mean_age = mean(Age, na.rm = TRUE)) |>
pull(mean_age)
min_age <- players_data |>
summarize(min_age = min(Age, na.rm  = TRUE)) |>
pull(min_age)
max_age <- players_data |>
summarize(max_age = max(Age, na.rm = TRUE)) |>
pull(max_age)
mean_age
min_age
max_age
# Out:
# [1] 21.13918
# [1] 9
# [1] 58

# %%
prop_level <- players_data |>
count(experience) |>
mutate(prop = n / sum(n) * 100)
prop_level
# Out:
#   experience n  prop
# 1 Amateur    63 32.142857
# 2 Beginner   35 17.857143
# 3 Pro        14  7.142857
# 4 Regular    36 18.367347
# 5 Veteran    48 24.489796

# %%
prop_gender <- players_data |>
count(gender) |>
mutate(prop = n / sum(n) * 100)
prop_gender
# Out:
#   gender            n   prop
# 1 Agender             2  1.0204082
# 2 Female             37 18.8775510
# 3 Male              124 63.2653061
# 4 Non-binary         15  7.6530612
# 5 Other               1  0.5102041
# 6 Prefer not to say  11  5.6122449
# 7 Two-Spirited        6  3.0612245

# %%
mean_hours <- players_data |>
summarize(mean_hours = mean(played_hours, na.rm = TRUE)) |>
pull(mean_hours)
min_hours <- players_data |>
summarize(min_hours = min(played_hours, na.rm  = TRUE)) |>
pull(min_hours)
max_hours <- players_data |>
summarize(max_hours = max(played_hours, na.rm = TRUE)) |>
pull(max_hours)
mean_hours
min_hours
max_hours
# Out:
# [1] 5.845918
# [1] 0
# [1] 223.1
